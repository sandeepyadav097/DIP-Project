# %%
import numpy as np

import cv2
import signal

from functools import wraps
import errno
import os
import copy

image = cv2.imread('cataract.jpg')
image = cv2.resize(image, (256, 256))
orig_image = np.copy(image)

output = image.copy()
gray=image
gray = cv2.GaussianBlur(gray,(9,9),0.5)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#gray= cv2.resize(gray, (256, 256)) 
cv2.imshow("gray", gray)
cv2.waitKey()

circles = None

minimum_circle_size = 60      #this is the range of possible circle in pixels you want to find
maximum_circle_size = 70     #maximum possible circle size you're willing to find in pixels

guess_dp = 1.0

number_of_circles_expected = 1          #we expect to find just one circle
breakout = False

max_guess_accumulator_array_threshold = 100     #minimum of 1, no maximum, (max 300?) the quantity of votes 
                                                #needed to qualify for a circle to be found.
circleLog = []

guess_accumulator_array_threshold = max_guess_accumulator_array_threshold

while guess_accumulator_array_threshold > 1 and breakout == False:
    #start out with smallest resolution possible, to find the most precise circle, then creep bigger if none found
    guess_dp = 1.0
    print("resetting guess_dp:" + str(guess_dp))
    while guess_dp < 9 and breakout == False:
        guess_radius = maximum_circle_size
        print("setting guess_radius: " + str(guess_radius))
        print(circles is None)
        while True:

            #HoughCircles algorithm isn't strong enough to stand on its own if you don't
            #know EXACTLY what radius the circle in the image is, (accurate to within 3 pixels) 
            #If you don't know radius, you need lots of guess and check and lots of post-processing 
            #verification.  Luckily HoughCircles is pretty quick so we can brute force.

            print("guessing radius: " + str(guess_radius) + 
                    " and dp: " + str(guess_dp) + " vote threshold: " + 
                    str(guess_accumulator_array_threshold))

            circles = cv2.HoughCircles(gray, 
                cv2.HOUGH_GRADIENT, 
                dp=guess_dp,               #resolution of accumulator array.
                minDist=100,                #number of pixels center of circles should be from each other, hardcode
                param1=50,
                param2=guess_accumulator_array_threshold,
                minRadius=(guess_radius-3),    #HoughCircles will look for circles at minimum this size
                maxRadius=(guess_radius+3)     #HoughCircles will look for circles at maximum this size
                )

            if circles is not None:
                if len(circles[0]) == number_of_circles_expected:
                    print("len of circles: " + str(len(circles)))
                    circleLog.append(copy.copy(circles))
                    print("k1")
                break
                circles = None
            guess_radius -= 5 
            if guess_radius < 40:
                break;

        guess_dp += 1.5

    guess_accumulator_array_threshold -= 2

#Return the circleLog with the highest accumulator threshold
print(circles)

# ensure at least some circles were found
for cir in circleLog:
    # convert the (x, y) coordinates and radius of the circles to integers
    output = np.copy(orig_image)

    if (len(cir) > 1):
        print("FAIL before")
        exit()

    print(cir[0, :])

    cir = np.round(cir[0, :]).astype("int")

    for (x, y, r) in cir:
        cv2.circle(output, (x, y), r, (0, 0, 255), 2)
        cv2.rectangle(output, (x - 5, y - 5), (x + 5, y + 5), (0, 128, 255), -1)

    cv2.imshow("output", np.hstack([orig_image, output]))
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 100
# guessing radius: 65 and dp: 1.0 vote threshold: 100
# guessing radius: 60 and dp: 1.0 vote threshold: 100
# guessing radius: 55 and dp: 1.0 vote threshold: 100
# guessing radius: 50 and dp: 1.0 vote threshold: 100
# guessing radius: 45 and dp: 1.0 vote threshold: 100
# guessing radius: 40 and dp: 1.0 vote threshold: 100
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 100
# guessing radius: 65 and dp: 2.5 vote threshold: 100
# guessing radius: 60 and dp: 2.5 vote threshold: 100
# guessing radius: 55 and dp: 2.5 vote threshold: 100
# guessing radius: 50 and dp: 2.5 vote threshold: 100
# guessing radius: 45 and dp: 2.5 vote threshold: 100
# guessing radius: 40 and dp: 2.5 vote threshold: 100
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 100
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 100
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 100
# guessing radius: 65 and dp: 7.0 vote threshold: 100
# guessing radius: 60 and dp: 7.0 vote threshold: 100
# guessing radius: 55 and dp: 7.0 vote threshold: 100
# guessing radius: 50 and dp: 7.0 vote threshold: 100
# guessing radius: 45 and dp: 7.0 vote threshold: 100
# guessing radius: 40 and dp: 7.0 vote threshold: 100
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 100
# guessing radius: 65 and dp: 8.5 vote threshold: 100
# guessing radius: 60 and dp: 8.5 vote threshold: 100
# guessing radius: 55 and dp: 8.5 vote threshold: 100
# guessing radius: 50 and dp: 8.5 vote threshold: 100
# guessing radius: 45 and dp: 8.5 vote threshold: 100
# guessing radius: 40 and dp: 8.5 vote threshold: 100
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 98
# guessing radius: 65 and dp: 1.0 vote threshold: 98
# guessing radius: 60 and dp: 1.0 vote threshold: 98
# guessing radius: 55 and dp: 1.0 vote threshold: 98
# guessing radius: 50 and dp: 1.0 vote threshold: 98
# guessing radius: 45 and dp: 1.0 vote threshold: 98
# guessing radius: 40 and dp: 1.0 vote threshold: 98
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 98
# guessing radius: 65 and dp: 2.5 vote threshold: 98
# guessing radius: 60 and dp: 2.5 vote threshold: 98
# guessing radius: 55 and dp: 2.5 vote threshold: 98
# guessing radius: 50 and dp: 2.5 vote threshold: 98
# guessing radius: 45 and dp: 2.5 vote threshold: 98
# guessing radius: 40 and dp: 2.5 vote threshold: 98
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 98
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 98
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 98
# guessing radius: 65 and dp: 7.0 vote threshold: 98
# guessing radius: 60 and dp: 7.0 vote threshold: 98
# guessing radius: 55 and dp: 7.0 vote threshold: 98
# guessing radius: 50 and dp: 7.0 vote threshold: 98
# guessing radius: 45 and dp: 7.0 vote threshold: 98
# guessing radius: 40 and dp: 7.0 vote threshold: 98
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 98
# guessing radius: 65 and dp: 8.5 vote threshold: 98
# guessing radius: 60 and dp: 8.5 vote threshold: 98
# guessing radius: 55 and dp: 8.5 vote threshold: 98
# guessing radius: 50 and dp: 8.5 vote threshold: 98
# guessing radius: 45 and dp: 8.5 vote threshold: 98
# guessing radius: 40 and dp: 8.5 vote threshold: 98
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 96
# guessing radius: 65 and dp: 1.0 vote threshold: 96
# guessing radius: 60 and dp: 1.0 vote threshold: 96
# guessing radius: 55 and dp: 1.0 vote threshold: 96
# guessing radius: 50 and dp: 1.0 vote threshold: 96
# guessing radius: 45 and dp: 1.0 vote threshold: 96
# guessing radius: 40 and dp: 1.0 vote threshold: 96
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 96
# guessing radius: 65 and dp: 2.5 vote threshold: 96
# guessing radius: 60 and dp: 2.5 vote threshold: 96
# guessing radius: 55 and dp: 2.5 vote threshold: 96
# guessing radius: 50 and dp: 2.5 vote threshold: 96
# guessing radius: 45 and dp: 2.5 vote threshold: 96
# guessing radius: 40 and dp: 2.5 vote threshold: 96
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 96
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 96
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 96
# guessing radius: 65 and dp: 7.0 vote threshold: 96
# guessing radius: 60 and dp: 7.0 vote threshold: 96
# guessing radius: 55 and dp: 7.0 vote threshold: 96
# guessing radius: 50 and dp: 7.0 vote threshold: 96
# guessing radius: 45 and dp: 7.0 vote threshold: 96
# guessing radius: 40 and dp: 7.0 vote threshold: 96
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 96
# guessing radius: 65 and dp: 8.5 vote threshold: 96
# guessing radius: 60 and dp: 8.5 vote threshold: 96
# guessing radius: 55 and dp: 8.5 vote threshold: 96
# guessing radius: 50 and dp: 8.5 vote threshold: 96
# guessing radius: 45 and dp: 8.5 vote threshold: 96
# guessing radius: 40 and dp: 8.5 vote threshold: 96
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 94
# guessing radius: 65 and dp: 1.0 vote threshold: 94
# guessing radius: 60 and dp: 1.0 vote threshold: 94
# guessing radius: 55 and dp: 1.0 vote threshold: 94
# guessing radius: 50 and dp: 1.0 vote threshold: 94
# guessing radius: 45 and dp: 1.0 vote threshold: 94
# guessing radius: 40 and dp: 1.0 vote threshold: 94
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 94
# guessing radius: 65 and dp: 2.5 vote threshold: 94
# guessing radius: 60 and dp: 2.5 vote threshold: 94
# guessing radius: 55 and dp: 2.5 vote threshold: 94
# guessing radius: 50 and dp: 2.5 vote threshold: 94
# guessing radius: 45 and dp: 2.5 vote threshold: 94
# guessing radius: 40 and dp: 2.5 vote threshold: 94
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 94
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 94
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 94
# guessing radius: 65 and dp: 7.0 vote threshold: 94
# guessing radius: 60 and dp: 7.0 vote threshold: 94
# guessing radius: 55 and dp: 7.0 vote threshold: 94
# guessing radius: 50 and dp: 7.0 vote threshold: 94
# guessing radius: 45 and dp: 7.0 vote threshold: 94
# guessing radius: 40 and dp: 7.0 vote threshold: 94
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 94
# guessing radius: 65 and dp: 8.5 vote threshold: 94
# guessing radius: 60 and dp: 8.5 vote threshold: 94
# guessing radius: 55 and dp: 8.5 vote threshold: 94
# guessing radius: 50 and dp: 8.5 vote threshold: 94
# guessing radius: 45 and dp: 8.5 vote threshold: 94
# guessing radius: 40 and dp: 8.5 vote threshold: 94
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 92
# guessing radius: 65 and dp: 1.0 vote threshold: 92
# guessing radius: 60 and dp: 1.0 vote threshold: 92
# guessing radius: 55 and dp: 1.0 vote threshold: 92
# guessing radius: 50 and dp: 1.0 vote threshold: 92
# guessing radius: 45 and dp: 1.0 vote threshold: 92
# guessing radius: 40 and dp: 1.0 vote threshold: 92
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 92
# guessing radius: 65 and dp: 2.5 vote threshold: 92
# guessing radius: 60 and dp: 2.5 vote threshold: 92
# guessing radius: 55 and dp: 2.5 vote threshold: 92
# guessing radius: 50 and dp: 2.5 vote threshold: 92
# guessing radius: 45 and dp: 2.5 vote threshold: 92
# guessing radius: 40 and dp: 2.5 vote threshold: 92
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 92
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 92
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 92
# guessing radius: 65 and dp: 7.0 vote threshold: 92
# guessing radius: 60 and dp: 7.0 vote threshold: 92
# guessing radius: 55 and dp: 7.0 vote threshold: 92
# guessing radius: 50 and dp: 7.0 vote threshold: 92
# guessing radius: 45 and dp: 7.0 vote threshold: 92
# guessing radius: 40 and dp: 7.0 vote threshold: 92
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 92
# guessing radius: 65 and dp: 8.5 vote threshold: 92
# guessing radius: 60 and dp: 8.5 vote threshold: 92
# guessing radius: 55 and dp: 8.5 vote threshold: 92
# guessing radius: 50 and dp: 8.5 vote threshold: 92
# guessing radius: 45 and dp: 8.5 vote threshold: 92
# guessing radius: 40 and dp: 8.5 vote threshold: 92
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 90
# guessing radius: 65 and dp: 1.0 vote threshold: 90
# guessing radius: 60 and dp: 1.0 vote threshold: 90
# guessing radius: 55 and dp: 1.0 vote threshold: 90
# guessing radius: 50 and dp: 1.0 vote threshold: 90
# guessing radius: 45 and dp: 1.0 vote threshold: 90
# guessing radius: 40 and dp: 1.0 vote threshold: 90
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 90
# guessing radius: 65 and dp: 2.5 vote threshold: 90
# guessing radius: 60 and dp: 2.5 vote threshold: 90
# guessing radius: 55 and dp: 2.5 vote threshold: 90
# guessing radius: 50 and dp: 2.5 vote threshold: 90
# guessing radius: 45 and dp: 2.5 vote threshold: 90
# guessing radius: 40 and dp: 2.5 vote threshold: 90
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 90
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 90
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 90
# guessing radius: 65 and dp: 7.0 vote threshold: 90
# guessing radius: 60 and dp: 7.0 vote threshold: 90
# guessing radius: 55 and dp: 7.0 vote threshold: 90
# guessing radius: 50 and dp: 7.0 vote threshold: 90
# guessing radius: 45 and dp: 7.0 vote threshold: 90
# guessing radius: 40 and dp: 7.0 vote threshold: 90
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 90
# guessing radius: 65 and dp: 8.5 vote threshold: 90
# guessing radius: 60 and dp: 8.5 vote threshold: 90
# guessing radius: 55 and dp: 8.5 vote threshold: 90
# guessing radius: 50 and dp: 8.5 vote threshold: 90
# guessing radius: 45 and dp: 8.5 vote threshold: 90
# guessing radius: 40 and dp: 8.5 vote threshold: 90
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 88
# guessing radius: 65 and dp: 1.0 vote threshold: 88
# guessing radius: 60 and dp: 1.0 vote threshold: 88
# guessing radius: 55 and dp: 1.0 vote threshold: 88
# guessing radius: 50 and dp: 1.0 vote threshold: 88
# guessing radius: 45 and dp: 1.0 vote threshold: 88
# guessing radius: 40 and dp: 1.0 vote threshold: 88
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 88
# guessing radius: 65 and dp: 2.5 vote threshold: 88
# guessing radius: 60 and dp: 2.5 vote threshold: 88
# guessing radius: 55 and dp: 2.5 vote threshold: 88
# guessing radius: 50 and dp: 2.5 vote threshold: 88
# guessing radius: 45 and dp: 2.5 vote threshold: 88
# guessing radius: 40 and dp: 2.5 vote threshold: 88
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 88
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 88
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 88
# guessing radius: 65 and dp: 7.0 vote threshold: 88
# guessing radius: 60 and dp: 7.0 vote threshold: 88
# guessing radius: 55 and dp: 7.0 vote threshold: 88
# guessing radius: 50 and dp: 7.0 vote threshold: 88
# guessing radius: 45 and dp: 7.0 vote threshold: 88
# guessing radius: 40 and dp: 7.0 vote threshold: 88
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 88
# guessing radius: 65 and dp: 8.5 vote threshold: 88
# guessing radius: 60 and dp: 8.5 vote threshold: 88
# guessing radius: 55 and dp: 8.5 vote threshold: 88
# guessing radius: 50 and dp: 8.5 vote threshold: 88
# guessing radius: 45 and dp: 8.5 vote threshold: 88
# guessing radius: 40 and dp: 8.5 vote threshold: 88
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 86
# guessing radius: 65 and dp: 1.0 vote threshold: 86
# guessing radius: 60 and dp: 1.0 vote threshold: 86
# guessing radius: 55 and dp: 1.0 vote threshold: 86
# guessing radius: 50 and dp: 1.0 vote threshold: 86
# guessing radius: 45 and dp: 1.0 vote threshold: 86
# guessing radius: 40 and dp: 1.0 vote threshold: 86
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 86
# guessing radius: 65 and dp: 2.5 vote threshold: 86
# guessing radius: 60 and dp: 2.5 vote threshold: 86
# guessing radius: 55 and dp: 2.5 vote threshold: 86
# guessing radius: 50 and dp: 2.5 vote threshold: 86
# guessing radius: 45 and dp: 2.5 vote threshold: 86
# guessing radius: 40 and dp: 2.5 vote threshold: 86
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 86
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 86
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 86
# guessing radius: 65 and dp: 7.0 vote threshold: 86
# guessing radius: 60 and dp: 7.0 vote threshold: 86
# guessing radius: 55 and dp: 7.0 vote threshold: 86
# guessing radius: 50 and dp: 7.0 vote threshold: 86
# guessing radius: 45 and dp: 7.0 vote threshold: 86
# guessing radius: 40 and dp: 7.0 vote threshold: 86
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 86
# guessing radius: 65 and dp: 8.5 vote threshold: 86
# guessing radius: 60 and dp: 8.5 vote threshold: 86
# guessing radius: 55 and dp: 8.5 vote threshold: 86
# guessing radius: 50 and dp: 8.5 vote threshold: 86
# guessing radius: 45 and dp: 8.5 vote threshold: 86
# guessing radius: 40 and dp: 8.5 vote threshold: 86
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 84
# guessing radius: 65 and dp: 1.0 vote threshold: 84
# guessing radius: 60 and dp: 1.0 vote threshold: 84
# guessing radius: 55 and dp: 1.0 vote threshold: 84
# guessing radius: 50 and dp: 1.0 vote threshold: 84
# guessing radius: 45 and dp: 1.0 vote threshold: 84
# guessing radius: 40 and dp: 1.0 vote threshold: 84
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 84
# guessing radius: 65 and dp: 2.5 vote threshold: 84
# guessing radius: 60 and dp: 2.5 vote threshold: 84
# guessing radius: 55 and dp: 2.5 vote threshold: 84
# guessing radius: 50 and dp: 2.5 vote threshold: 84
# guessing radius: 45 and dp: 2.5 vote threshold: 84
# guessing radius: 40 and dp: 2.5 vote threshold: 84
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 4.0 vote threshold: 84
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 84
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 84
# guessing radius: 65 and dp: 7.0 vote threshold: 84
# guessing radius: 60 and dp: 7.0 vote threshold: 84
# guessing radius: 55 and dp: 7.0 vote threshold: 84
# guessing radius: 50 and dp: 7.0 vote threshold: 84
# guessing radius: 45 and dp: 7.0 vote threshold: 84
# guessing radius: 40 and dp: 7.0 vote threshold: 84
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 84
# guessing radius: 65 and dp: 8.5 vote threshold: 84
# guessing radius: 60 and dp: 8.5 vote threshold: 84
# guessing radius: 55 and dp: 8.5 vote threshold: 84
# guessing radius: 50 and dp: 8.5 vote threshold: 84
# guessing radius: 45 and dp: 8.5 vote threshold: 84
# guessing radius: 40 and dp: 8.5 vote threshold: 84
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 82
# guessing radius: 65 and dp: 1.0 vote threshold: 82
# guessing radius: 60 and dp: 1.0 vote threshold: 82
# guessing radius: 55 and dp: 1.0 vote threshold: 82
# guessing radius: 50 and dp: 1.0 vote threshold: 82
# guessing radius: 45 and dp: 1.0 vote threshold: 82
# guessing radius: 40 and dp: 1.0 vote threshold: 82
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 82
# guessing radius: 65 and dp: 2.5 vote threshold: 82
# guessing radius: 60 and dp: 2.5 vote threshold: 82
# guessing radius: 55 and dp: 2.5 vote threshold: 82
# guessing radius: 50 and dp: 2.5 vote threshold: 82
# guessing radius: 45 and dp: 2.5 vote threshold: 82
# guessing radius: 40 and dp: 2.5 vote threshold: 82
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 82
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 82
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 82
# guessing radius: 65 and dp: 7.0 vote threshold: 82
# guessing radius: 60 and dp: 7.0 vote threshold: 82
# guessing radius: 55 and dp: 7.0 vote threshold: 82
# guessing radius: 50 and dp: 7.0 vote threshold: 82
# guessing radius: 45 and dp: 7.0 vote threshold: 82
# guessing radius: 40 and dp: 7.0 vote threshold: 82
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 82
# guessing radius: 65 and dp: 8.5 vote threshold: 82
# guessing radius: 60 and dp: 8.5 vote threshold: 82
# guessing radius: 55 and dp: 8.5 vote threshold: 82
# guessing radius: 50 and dp: 8.5 vote threshold: 82
# guessing radius: 45 and dp: 8.5 vote threshold: 82
# guessing radius: 40 and dp: 8.5 vote threshold: 82
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 80
# guessing radius: 65 and dp: 1.0 vote threshold: 80
# guessing radius: 60 and dp: 1.0 vote threshold: 80
# guessing radius: 55 and dp: 1.0 vote threshold: 80
# guessing radius: 50 and dp: 1.0 vote threshold: 80
# guessing radius: 45 and dp: 1.0 vote threshold: 80
# guessing radius: 40 and dp: 1.0 vote threshold: 80
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 80
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 80
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 80
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 80
# guessing radius: 65 and dp: 7.0 vote threshold: 80
# guessing radius: 60 and dp: 7.0 vote threshold: 80
# guessing radius: 55 and dp: 7.0 vote threshold: 80
# guessing radius: 50 and dp: 7.0 vote threshold: 80
# guessing radius: 45 and dp: 7.0 vote threshold: 80
# guessing radius: 40 and dp: 7.0 vote threshold: 80
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 80
# guessing radius: 65 and dp: 8.5 vote threshold: 80
# guessing radius: 60 and dp: 8.5 vote threshold: 80
# guessing radius: 55 and dp: 8.5 vote threshold: 80
# guessing radius: 50 and dp: 8.5 vote threshold: 80
# guessing radius: 45 and dp: 8.5 vote threshold: 80
# guessing radius: 40 and dp: 8.5 vote threshold: 80
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 78
# guessing radius: 65 and dp: 1.0 vote threshold: 78
# guessing radius: 60 and dp: 1.0 vote threshold: 78
# guessing radius: 55 and dp: 1.0 vote threshold: 78
# guessing radius: 50 and dp: 1.0 vote threshold: 78
# guessing radius: 45 and dp: 1.0 vote threshold: 78
# guessing radius: 40 and dp: 1.0 vote threshold: 78
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 78
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 78
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 78
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 78
# guessing radius: 65 and dp: 7.0 vote threshold: 78
# guessing radius: 60 and dp: 7.0 vote threshold: 78
# guessing radius: 55 and dp: 7.0 vote threshold: 78
# guessing radius: 50 and dp: 7.0 vote threshold: 78
# guessing radius: 45 and dp: 7.0 vote threshold: 78
# guessing radius: 40 and dp: 7.0 vote threshold: 78
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 78
# guessing radius: 65 and dp: 8.5 vote threshold: 78
# guessing radius: 60 and dp: 8.5 vote threshold: 78
# guessing radius: 55 and dp: 8.5 vote threshold: 78
# guessing radius: 50 and dp: 8.5 vote threshold: 78
# guessing radius: 45 and dp: 8.5 vote threshold: 78
# guessing radius: 40 and dp: 8.5 vote threshold: 78
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 76
# guessing radius: 65 and dp: 1.0 vote threshold: 76
# guessing radius: 60 and dp: 1.0 vote threshold: 76
# guessing radius: 55 and dp: 1.0 vote threshold: 76
# guessing radius: 50 and dp: 1.0 vote threshold: 76
# guessing radius: 45 and dp: 1.0 vote threshold: 76
# guessing radius: 40 and dp: 1.0 vote threshold: 76
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 76
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 76
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 76
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 76
# guessing radius: 65 and dp: 7.0 vote threshold: 76
# guessing radius: 60 and dp: 7.0 vote threshold: 76
# guessing radius: 55 and dp: 7.0 vote threshold: 76
# guessing radius: 50 and dp: 7.0 vote threshold: 76
# guessing radius: 45 and dp: 7.0 vote threshold: 76
# guessing radius: 40 and dp: 7.0 vote threshold: 76
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 76
# guessing radius: 65 and dp: 8.5 vote threshold: 76
# guessing radius: 60 and dp: 8.5 vote threshold: 76
# guessing radius: 55 and dp: 8.5 vote threshold: 76
# guessing radius: 50 and dp: 8.5 vote threshold: 76
# guessing radius: 45 and dp: 8.5 vote threshold: 76
# guessing radius: 40 and dp: 8.5 vote threshold: 76
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 74
# guessing radius: 65 and dp: 1.0 vote threshold: 74
# guessing radius: 60 and dp: 1.0 vote threshold: 74
# guessing radius: 55 and dp: 1.0 vote threshold: 74
# guessing radius: 50 and dp: 1.0 vote threshold: 74
# guessing radius: 45 and dp: 1.0 vote threshold: 74
# guessing radius: 40 and dp: 1.0 vote threshold: 74
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 74
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 74
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 74
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 74
# guessing radius: 65 and dp: 7.0 vote threshold: 74
# guessing radius: 60 and dp: 7.0 vote threshold: 74
# guessing radius: 55 and dp: 7.0 vote threshold: 74
# guessing radius: 50 and dp: 7.0 vote threshold: 74
# guessing radius: 45 and dp: 7.0 vote threshold: 74
# guessing radius: 40 and dp: 7.0 vote threshold: 74
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 74
# guessing radius: 65 and dp: 8.5 vote threshold: 74
# guessing radius: 60 and dp: 8.5 vote threshold: 74
# guessing radius: 55 and dp: 8.5 vote threshold: 74
# guessing radius: 50 and dp: 8.5 vote threshold: 74
# guessing radius: 45 and dp: 8.5 vote threshold: 74
# guessing radius: 40 and dp: 8.5 vote threshold: 74
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 72
# guessing radius: 65 and dp: 1.0 vote threshold: 72
# guessing radius: 60 and dp: 1.0 vote threshold: 72
# guessing radius: 55 and dp: 1.0 vote threshold: 72
# guessing radius: 50 and dp: 1.0 vote threshold: 72
# guessing radius: 45 and dp: 1.0 vote threshold: 72
# guessing radius: 40 and dp: 1.0 vote threshold: 72
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 72
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 72
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 72
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 72
# guessing radius: 65 and dp: 7.0 vote threshold: 72
# guessing radius: 60 and dp: 7.0 vote threshold: 72
# guessing radius: 55 and dp: 7.0 vote threshold: 72
# guessing radius: 50 and dp: 7.0 vote threshold: 72
# guessing radius: 45 and dp: 7.0 vote threshold: 72
# guessing radius: 40 and dp: 7.0 vote threshold: 72
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 72
# guessing radius: 65 and dp: 8.5 vote threshold: 72
# guessing radius: 60 and dp: 8.5 vote threshold: 72
# guessing radius: 55 and dp: 8.5 vote threshold: 72
# guessing radius: 50 and dp: 8.5 vote threshold: 72
# guessing radius: 45 and dp: 8.5 vote threshold: 72
# guessing radius: 40 and dp: 8.5 vote threshold: 72
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 70
# guessing radius: 65 and dp: 1.0 vote threshold: 70
# guessing radius: 60 and dp: 1.0 vote threshold: 70
# guessing radius: 55 and dp: 1.0 vote threshold: 70
# guessing radius: 50 and dp: 1.0 vote threshold: 70
# guessing radius: 45 and dp: 1.0 vote threshold: 70
# guessing radius: 40 and dp: 1.0 vote threshold: 70
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 70
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 70
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 70
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 70
# guessing radius: 65 and dp: 7.0 vote threshold: 70
# guessing radius: 60 and dp: 7.0 vote threshold: 70
# guessing radius: 55 and dp: 7.0 vote threshold: 70
# guessing radius: 50 and dp: 7.0 vote threshold: 70
# guessing radius: 45 and dp: 7.0 vote threshold: 70
# guessing radius: 40 and dp: 7.0 vote threshold: 70
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 70
# guessing radius: 65 and dp: 8.5 vote threshold: 70
# guessing radius: 60 and dp: 8.5 vote threshold: 70
# guessing radius: 55 and dp: 8.5 vote threshold: 70
# guessing radius: 50 and dp: 8.5 vote threshold: 70
# guessing radius: 45 and dp: 8.5 vote threshold: 70
# guessing radius: 40 and dp: 8.5 vote threshold: 70
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 68
# guessing radius: 65 and dp: 1.0 vote threshold: 68
# guessing radius: 60 and dp: 1.0 vote threshold: 68
# guessing radius: 55 and dp: 1.0 vote threshold: 68
# guessing radius: 50 and dp: 1.0 vote threshold: 68
# guessing radius: 45 and dp: 1.0 vote threshold: 68
# guessing radius: 40 and dp: 1.0 vote threshold: 68
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 68
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 68
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 68
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 68
# guessing radius: 65 and dp: 7.0 vote threshold: 68
# guessing radius: 60 and dp: 7.0 vote threshold: 68
# guessing radius: 55 and dp: 7.0 vote threshold: 68
# guessing radius: 50 and dp: 7.0 vote threshold: 68
# guessing radius: 45 and dp: 7.0 vote threshold: 68
# guessing radius: 40 and dp: 7.0 vote threshold: 68
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 68
# guessing radius: 65 and dp: 8.5 vote threshold: 68
# guessing radius: 60 and dp: 8.5 vote threshold: 68
# guessing radius: 55 and dp: 8.5 vote threshold: 68
# guessing radius: 50 and dp: 8.5 vote threshold: 68
# guessing radius: 45 and dp: 8.5 vote threshold: 68
# guessing radius: 40 and dp: 8.5 vote threshold: 68
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 66
# guessing radius: 65 and dp: 1.0 vote threshold: 66
# guessing radius: 60 and dp: 1.0 vote threshold: 66
# guessing radius: 55 and dp: 1.0 vote threshold: 66
# guessing radius: 50 and dp: 1.0 vote threshold: 66
# guessing radius: 45 and dp: 1.0 vote threshold: 66
# guessing radius: 40 and dp: 1.0 vote threshold: 66
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 66
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 66
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 66
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 66
# guessing radius: 65 and dp: 7.0 vote threshold: 66
# guessing radius: 60 and dp: 7.0 vote threshold: 66
# guessing radius: 55 and dp: 7.0 vote threshold: 66
# guessing radius: 50 and dp: 7.0 vote threshold: 66
# guessing radius: 45 and dp: 7.0 vote threshold: 66
# guessing radius: 40 and dp: 7.0 vote threshold: 66
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 66
# guessing radius: 65 and dp: 8.5 vote threshold: 66
# guessing radius: 60 and dp: 8.5 vote threshold: 66
# guessing radius: 55 and dp: 8.5 vote threshold: 66
# guessing radius: 50 and dp: 8.5 vote threshold: 66
# guessing radius: 45 and dp: 8.5 vote threshold: 66
# guessing radius: 40 and dp: 8.5 vote threshold: 66
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 64
# guessing radius: 65 and dp: 1.0 vote threshold: 64
# guessing radius: 60 and dp: 1.0 vote threshold: 64
# guessing radius: 55 and dp: 1.0 vote threshold: 64
# guessing radius: 50 and dp: 1.0 vote threshold: 64
# guessing radius: 45 and dp: 1.0 vote threshold: 64
# guessing radius: 40 and dp: 1.0 vote threshold: 64
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 64
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 64
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 64
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 64
# guessing radius: 65 and dp: 7.0 vote threshold: 64
# guessing radius: 60 and dp: 7.0 vote threshold: 64
# guessing radius: 55 and dp: 7.0 vote threshold: 64
# guessing radius: 50 and dp: 7.0 vote threshold: 64
# guessing radius: 45 and dp: 7.0 vote threshold: 64
# guessing radius: 40 and dp: 7.0 vote threshold: 64
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 64
# guessing radius: 65 and dp: 8.5 vote threshold: 64
# guessing radius: 60 and dp: 8.5 vote threshold: 64
# guessing radius: 55 and dp: 8.5 vote threshold: 64
# guessing radius: 50 and dp: 8.5 vote threshold: 64
# guessing radius: 45 and dp: 8.5 vote threshold: 64
# guessing radius: 40 and dp: 8.5 vote threshold: 64
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 62
# guessing radius: 65 and dp: 1.0 vote threshold: 62
# guessing radius: 60 and dp: 1.0 vote threshold: 62
# guessing radius: 55 and dp: 1.0 vote threshold: 62
# guessing radius: 50 and dp: 1.0 vote threshold: 62
# guessing radius: 45 and dp: 1.0 vote threshold: 62
# guessing radius: 40 and dp: 1.0 vote threshold: 62
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 62
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 62
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 62
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 62
# guessing radius: 65 and dp: 7.0 vote threshold: 62
# guessing radius: 60 and dp: 7.0 vote threshold: 62
# guessing radius: 55 and dp: 7.0 vote threshold: 62
# guessing radius: 50 and dp: 7.0 vote threshold: 62
# guessing radius: 45 and dp: 7.0 vote threshold: 62
# guessing radius: 40 and dp: 7.0 vote threshold: 62
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 62
# guessing radius: 65 and dp: 8.5 vote threshold: 62
# guessing radius: 60 and dp: 8.5 vote threshold: 62
# guessing radius: 55 and dp: 8.5 vote threshold: 62
# guessing radius: 50 and dp: 8.5 vote threshold: 62
# guessing radius: 45 and dp: 8.5 vote threshold: 62
# guessing radius: 40 and dp: 8.5 vote threshold: 62
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 60
# guessing radius: 65 and dp: 1.0 vote threshold: 60
# guessing radius: 60 and dp: 1.0 vote threshold: 60
# guessing radius: 55 and dp: 1.0 vote threshold: 60
# guessing radius: 50 and dp: 1.0 vote threshold: 60
# guessing radius: 45 and dp: 1.0 vote threshold: 60
# guessing radius: 40 and dp: 1.0 vote threshold: 60
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 60
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 60
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 60
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 60
# guessing radius: 65 and dp: 7.0 vote threshold: 60
# guessing radius: 60 and dp: 7.0 vote threshold: 60
# guessing radius: 55 and dp: 7.0 vote threshold: 60
# guessing radius: 50 and dp: 7.0 vote threshold: 60
# guessing radius: 45 and dp: 7.0 vote threshold: 60
# guessing radius: 40 and dp: 7.0 vote threshold: 60
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 60
# guessing radius: 65 and dp: 8.5 vote threshold: 60
# guessing radius: 60 and dp: 8.5 vote threshold: 60
# guessing radius: 55 and dp: 8.5 vote threshold: 60
# guessing radius: 50 and dp: 8.5 vote threshold: 60
# guessing radius: 45 and dp: 8.5 vote threshold: 60
# guessing radius: 40 and dp: 8.5 vote threshold: 60
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 58
# guessing radius: 65 and dp: 1.0 vote threshold: 58
# guessing radius: 60 and dp: 1.0 vote threshold: 58
# guessing radius: 55 and dp: 1.0 vote threshold: 58
# guessing radius: 50 and dp: 1.0 vote threshold: 58
# guessing radius: 45 and dp: 1.0 vote threshold: 58
# guessing radius: 40 and dp: 1.0 vote threshold: 58
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 58
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 58
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 58
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 58
# guessing radius: 65 and dp: 7.0 vote threshold: 58
# guessing radius: 60 and dp: 7.0 vote threshold: 58
# guessing radius: 55 and dp: 7.0 vote threshold: 58
# guessing radius: 50 and dp: 7.0 vote threshold: 58
# guessing radius: 45 and dp: 7.0 vote threshold: 58
# guessing radius: 40 and dp: 7.0 vote threshold: 58
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 58
# guessing radius: 65 and dp: 8.5 vote threshold: 58
# guessing radius: 60 and dp: 8.5 vote threshold: 58
# guessing radius: 55 and dp: 8.5 vote threshold: 58
# guessing radius: 50 and dp: 8.5 vote threshold: 58
# guessing radius: 45 and dp: 8.5 vote threshold: 58
# guessing radius: 40 and dp: 8.5 vote threshold: 58
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 56
# guessing radius: 65 and dp: 1.0 vote threshold: 56
# guessing radius: 60 and dp: 1.0 vote threshold: 56
# guessing radius: 55 and dp: 1.0 vote threshold: 56
# guessing radius: 50 and dp: 1.0 vote threshold: 56
# guessing radius: 45 and dp: 1.0 vote threshold: 56
# guessing radius: 40 and dp: 1.0 vote threshold: 56
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 56
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 56
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 56
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 56
# guessing radius: 65 and dp: 7.0 vote threshold: 56
# guessing radius: 60 and dp: 7.0 vote threshold: 56
# guessing radius: 55 and dp: 7.0 vote threshold: 56
# guessing radius: 50 and dp: 7.0 vote threshold: 56
# guessing radius: 45 and dp: 7.0 vote threshold: 56
# guessing radius: 40 and dp: 7.0 vote threshold: 56
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 56
# guessing radius: 65 and dp: 8.5 vote threshold: 56
# guessing radius: 60 and dp: 8.5 vote threshold: 56
# guessing radius: 55 and dp: 8.5 vote threshold: 56
# guessing radius: 50 and dp: 8.5 vote threshold: 56
# guessing radius: 45 and dp: 8.5 vote threshold: 56
# guessing radius: 40 and dp: 8.5 vote threshold: 56
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 54
# guessing radius: 65 and dp: 1.0 vote threshold: 54
# guessing radius: 60 and dp: 1.0 vote threshold: 54
# guessing radius: 55 and dp: 1.0 vote threshold: 54
# guessing radius: 50 and dp: 1.0 vote threshold: 54
# guessing radius: 45 and dp: 1.0 vote threshold: 54
# guessing radius: 40 and dp: 1.0 vote threshold: 54
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 54
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 54
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 54
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 54
# guessing radius: 65 and dp: 7.0 vote threshold: 54
# guessing radius: 60 and dp: 7.0 vote threshold: 54
# guessing radius: 55 and dp: 7.0 vote threshold: 54
# guessing radius: 50 and dp: 7.0 vote threshold: 54
# guessing radius: 45 and dp: 7.0 vote threshold: 54
# guessing radius: 40 and dp: 7.0 vote threshold: 54
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 54
# guessing radius: 65 and dp: 8.5 vote threshold: 54
# guessing radius: 60 and dp: 8.5 vote threshold: 54
# guessing radius: 55 and dp: 8.5 vote threshold: 54
# guessing radius: 50 and dp: 8.5 vote threshold: 54
# guessing radius: 45 and dp: 8.5 vote threshold: 54
# guessing radius: 40 and dp: 8.5 vote threshold: 54
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 52
# guessing radius: 65 and dp: 1.0 vote threshold: 52
# guessing radius: 60 and dp: 1.0 vote threshold: 52
# guessing radius: 55 and dp: 1.0 vote threshold: 52
# guessing radius: 50 and dp: 1.0 vote threshold: 52
# guessing radius: 45 and dp: 1.0 vote threshold: 52
# guessing radius: 40 and dp: 1.0 vote threshold: 52
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 52
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 52
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 52
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 52
# guessing radius: 65 and dp: 7.0 vote threshold: 52
# guessing radius: 60 and dp: 7.0 vote threshold: 52
# guessing radius: 55 and dp: 7.0 vote threshold: 52
# guessing radius: 50 and dp: 7.0 vote threshold: 52
# guessing radius: 45 and dp: 7.0 vote threshold: 52
# guessing radius: 40 and dp: 7.0 vote threshold: 52
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 52
# guessing radius: 65 and dp: 8.5 vote threshold: 52
# guessing radius: 60 and dp: 8.5 vote threshold: 52
# guessing radius: 55 and dp: 8.5 vote threshold: 52
# guessing radius: 50 and dp: 8.5 vote threshold: 52
# guessing radius: 45 and dp: 8.5 vote threshold: 52
# guessing radius: 40 and dp: 8.5 vote threshold: 52
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 50
# guessing radius: 65 and dp: 1.0 vote threshold: 50
# guessing radius: 60 and dp: 1.0 vote threshold: 50
# guessing radius: 55 and dp: 1.0 vote threshold: 50
# guessing radius: 50 and dp: 1.0 vote threshold: 50
# guessing radius: 45 and dp: 1.0 vote threshold: 50
# guessing radius: 40 and dp: 1.0 vote threshold: 50
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 50
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 50
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 50
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 50
# guessing radius: 65 and dp: 7.0 vote threshold: 50
# guessing radius: 60 and dp: 7.0 vote threshold: 50
# guessing radius: 55 and dp: 7.0 vote threshold: 50
# guessing radius: 50 and dp: 7.0 vote threshold: 50
# guessing radius: 45 and dp: 7.0 vote threshold: 50
# guessing radius: 40 and dp: 7.0 vote threshold: 50
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 50
# guessing radius: 65 and dp: 8.5 vote threshold: 50
# guessing radius: 60 and dp: 8.5 vote threshold: 50
# guessing radius: 55 and dp: 8.5 vote threshold: 50
# guessing radius: 50 and dp: 8.5 vote threshold: 50
# guessing radius: 45 and dp: 8.5 vote threshold: 50
# guessing radius: 40 and dp: 8.5 vote threshold: 50
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 48
# guessing radius: 65 and dp: 1.0 vote threshold: 48
# guessing radius: 60 and dp: 1.0 vote threshold: 48
# guessing radius: 55 and dp: 1.0 vote threshold: 48
# guessing radius: 50 and dp: 1.0 vote threshold: 48
# guessing radius: 45 and dp: 1.0 vote threshold: 48
# guessing radius: 40 and dp: 1.0 vote threshold: 48
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 48
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 48
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 48
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 48
# guessing radius: 65 and dp: 7.0 vote threshold: 48
# guessing radius: 60 and dp: 7.0 vote threshold: 48
# guessing radius: 55 and dp: 7.0 vote threshold: 48
# guessing radius: 50 and dp: 7.0 vote threshold: 48
# guessing radius: 45 and dp: 7.0 vote threshold: 48
# guessing radius: 40 and dp: 7.0 vote threshold: 48
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 48
# guessing radius: 65 and dp: 8.5 vote threshold: 48
# guessing radius: 60 and dp: 8.5 vote threshold: 48
# guessing radius: 55 and dp: 8.5 vote threshold: 48
# guessing radius: 50 and dp: 8.5 vote threshold: 48
# guessing radius: 45 and dp: 8.5 vote threshold: 48
# guessing radius: 40 and dp: 8.5 vote threshold: 48
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 46
# guessing radius: 65 and dp: 1.0 vote threshold: 46
# guessing radius: 60 and dp: 1.0 vote threshold: 46
# guessing radius: 55 and dp: 1.0 vote threshold: 46
# guessing radius: 50 and dp: 1.0 vote threshold: 46
# guessing radius: 45 and dp: 1.0 vote threshold: 46
# guessing radius: 40 and dp: 1.0 vote threshold: 46
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 46
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 46
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 46
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 46
# guessing radius: 65 and dp: 7.0 vote threshold: 46
# guessing radius: 60 and dp: 7.0 vote threshold: 46
# guessing radius: 55 and dp: 7.0 vote threshold: 46
# guessing radius: 50 and dp: 7.0 vote threshold: 46
# guessing radius: 45 and dp: 7.0 vote threshold: 46
# guessing radius: 40 and dp: 7.0 vote threshold: 46
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 46
# guessing radius: 65 and dp: 8.5 vote threshold: 46
# guessing radius: 60 and dp: 8.5 vote threshold: 46
# guessing radius: 55 and dp: 8.5 vote threshold: 46
# guessing radius: 50 and dp: 8.5 vote threshold: 46
# guessing radius: 45 and dp: 8.5 vote threshold: 46
# guessing radius: 40 and dp: 8.5 vote threshold: 46
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 44
# guessing radius: 65 and dp: 1.0 vote threshold: 44
# guessing radius: 60 and dp: 1.0 vote threshold: 44
# guessing radius: 55 and dp: 1.0 vote threshold: 44
# guessing radius: 50 and dp: 1.0 vote threshold: 44
# guessing radius: 45 and dp: 1.0 vote threshold: 44
# guessing radius: 40 and dp: 1.0 vote threshold: 44
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 44
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 44
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 44
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 44
# guessing radius: 65 and dp: 7.0 vote threshold: 44
# guessing radius: 60 and dp: 7.0 vote threshold: 44
# guessing radius: 55 and dp: 7.0 vote threshold: 44
# guessing radius: 50 and dp: 7.0 vote threshold: 44
# guessing radius: 45 and dp: 7.0 vote threshold: 44
# guessing radius: 40 and dp: 7.0 vote threshold: 44
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 44
# guessing radius: 65 and dp: 8.5 vote threshold: 44
# guessing radius: 60 and dp: 8.5 vote threshold: 44
# guessing radius: 55 and dp: 8.5 vote threshold: 44
# guessing radius: 50 and dp: 8.5 vote threshold: 44
# guessing radius: 45 and dp: 8.5 vote threshold: 44
# guessing radius: 40 and dp: 8.5 vote threshold: 44
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 42
# guessing radius: 65 and dp: 1.0 vote threshold: 42
# guessing radius: 60 and dp: 1.0 vote threshold: 42
# guessing radius: 55 and dp: 1.0 vote threshold: 42
# guessing radius: 50 and dp: 1.0 vote threshold: 42
# guessing radius: 45 and dp: 1.0 vote threshold: 42
# guessing radius: 40 and dp: 1.0 vote threshold: 42
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 42
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 42
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 42
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 42
# guessing radius: 65 and dp: 7.0 vote threshold: 42
# guessing radius: 60 and dp: 7.0 vote threshold: 42
# guessing radius: 55 and dp: 7.0 vote threshold: 42
# guessing radius: 50 and dp: 7.0 vote threshold: 42
# guessing radius: 45 and dp: 7.0 vote threshold: 42
# guessing radius: 40 and dp: 7.0 vote threshold: 42
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 42
# guessing radius: 65 and dp: 8.5 vote threshold: 42
# guessing radius: 60 and dp: 8.5 vote threshold: 42
# guessing radius: 55 and dp: 8.5 vote threshold: 42
# guessing radius: 50 and dp: 8.5 vote threshold: 42
# guessing radius: 45 and dp: 8.5 vote threshold: 42
# guessing radius: 40 and dp: 8.5 vote threshold: 42
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 40
# guessing radius: 65 and dp: 1.0 vote threshold: 40
# guessing radius: 60 and dp: 1.0 vote threshold: 40
# guessing radius: 55 and dp: 1.0 vote threshold: 40
# guessing radius: 50 and dp: 1.0 vote threshold: 40
# guessing radius: 45 and dp: 1.0 vote threshold: 40
# guessing radius: 40 and dp: 1.0 vote threshold: 40
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 40
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 40
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 40
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 40
# ...
# guessing radius: 55 and dp: 8.5 vote threshold: 24
# guessing radius: 50 and dp: 8.5 vote threshold: 24
# guessing radius: 45 and dp: 8.5 vote threshold: 24
# guessing radius: 40 and dp: 8.5 vote threshold: 24
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 22
# guessing radius: 65 and dp: 1.0 vote threshold: 22
# guessing radius: 60 and dp: 1.0 vote threshold: 22
# guessing radius: 55 and dp: 1.0 vote threshold: 22
# guessing radius: 50 and dp: 1.0 vote threshold: 22
# guessing radius: 45 and dp: 1.0 vote threshold: 22
# guessing radius: 40 and dp: 1.0 vote threshold: 22
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 22
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 22
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 22
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 22
# guessing radius: 65 and dp: 7.0 vote threshold: 22
# guessing radius: 60 and dp: 7.0 vote threshold: 22
# guessing radius: 55 and dp: 7.0 vote threshold: 22
# guessing radius: 50 and dp: 7.0 vote threshold: 22
# guessing radius: 45 and dp: 7.0 vote threshold: 22
# guessing radius: 40 and dp: 7.0 vote threshold: 22
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 22
# guessing radius: 65 and dp: 8.5 vote threshold: 22
# guessing radius: 60 and dp: 8.5 vote threshold: 22
# guessing radius: 55 and dp: 8.5 vote threshold: 22
# guessing radius: 50 and dp: 8.5 vote threshold: 22
# guessing radius: 45 and dp: 8.5 vote threshold: 22
# guessing radius: 40 and dp: 8.5 vote threshold: 22
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 20
# guessing radius: 65 and dp: 1.0 vote threshold: 20
# guessing radius: 60 and dp: 1.0 vote threshold: 20
# guessing radius: 55 and dp: 1.0 vote threshold: 20
# guessing radius: 50 and dp: 1.0 vote threshold: 20
# guessing radius: 45 and dp: 1.0 vote threshold: 20
# guessing radius: 40 and dp: 1.0 vote threshold: 20
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 2.5 vote threshold: 20
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 20
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 20
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 20
# guessing radius: 65 and dp: 7.0 vote threshold: 20
# guessing radius: 60 and dp: 7.0 vote threshold: 20
# guessing radius: 55 and dp: 7.0 vote threshold: 20
# guessing radius: 50 and dp: 7.0 vote threshold: 20
# guessing radius: 45 and dp: 7.0 vote threshold: 20
# guessing radius: 40 and dp: 7.0 vote threshold: 20
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 20
# guessing radius: 65 and dp: 8.5 vote threshold: 20
# guessing radius: 60 and dp: 8.5 vote threshold: 20
# guessing radius: 55 and dp: 8.5 vote threshold: 20
# guessing radius: 50 and dp: 8.5 vote threshold: 20
# guessing radius: 45 and dp: 8.5 vote threshold: 20
# guessing radius: 40 and dp: 8.5 vote threshold: 20
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 18
# guessing radius: 65 and dp: 1.0 vote threshold: 18
# guessing radius: 60 and dp: 1.0 vote threshold: 18
# guessing radius: 55 and dp: 1.0 vote threshold: 18
# guessing radius: 50 and dp: 1.0 vote threshold: 18
# guessing radius: 45 and dp: 1.0 vote threshold: 18
# guessing radius: 40 and dp: 1.0 vote threshold: 18
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 18
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 18
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 18
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 18
# guessing radius: 65 and dp: 7.0 vote threshold: 18
# guessing radius: 60 and dp: 7.0 vote threshold: 18
# guessing radius: 55 and dp: 7.0 vote threshold: 18
# guessing radius: 50 and dp: 7.0 vote threshold: 18
# guessing radius: 45 and dp: 7.0 vote threshold: 18
# guessing radius: 40 and dp: 7.0 vote threshold: 18
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 18
# guessing radius: 65 and dp: 8.5 vote threshold: 18
# guessing radius: 60 and dp: 8.5 vote threshold: 18
# guessing radius: 55 and dp: 8.5 vote threshold: 18
# guessing radius: 50 and dp: 8.5 vote threshold: 18
# guessing radius: 45 and dp: 8.5 vote threshold: 18
# guessing radius: 40 and dp: 8.5 vote threshold: 18
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 16
# guessing radius: 65 and dp: 1.0 vote threshold: 16
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 16
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 16
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 16
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 16
# guessing radius: 65 and dp: 7.0 vote threshold: 16
# guessing radius: 60 and dp: 7.0 vote threshold: 16
# guessing radius: 55 and dp: 7.0 vote threshold: 16
# guessing radius: 50 and dp: 7.0 vote threshold: 16
# guessing radius: 45 and dp: 7.0 vote threshold: 16
# guessing radius: 40 and dp: 7.0 vote threshold: 16
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 16
# guessing radius: 65 and dp: 8.5 vote threshold: 16
# guessing radius: 60 and dp: 8.5 vote threshold: 16
# guessing radius: 55 and dp: 8.5 vote threshold: 16
# guessing radius: 50 and dp: 8.5 vote threshold: 16
# guessing radius: 45 and dp: 8.5 vote threshold: 16
# guessing radius: 40 and dp: 8.5 vote threshold: 16
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 14
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 14
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 14
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 14
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 14
# guessing radius: 65 and dp: 7.0 vote threshold: 14
# guessing radius: 60 and dp: 7.0 vote threshold: 14
# guessing radius: 55 and dp: 7.0 vote threshold: 14
# guessing radius: 50 and dp: 7.0 vote threshold: 14
# guessing radius: 45 and dp: 7.0 vote threshold: 14
# guessing radius: 40 and dp: 7.0 vote threshold: 14
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 14
# guessing radius: 65 and dp: 8.5 vote threshold: 14
# guessing radius: 60 and dp: 8.5 vote threshold: 14
# guessing radius: 55 and dp: 8.5 vote threshold: 14
# guessing radius: 50 and dp: 8.5 vote threshold: 14
# guessing radius: 45 and dp: 8.5 vote threshold: 14
# guessing radius: 40 and dp: 8.5 vote threshold: 14
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 12
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 12
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 12
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 12
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 12
# guessing radius: 65 and dp: 7.0 vote threshold: 12
# guessing radius: 60 and dp: 7.0 vote threshold: 12
# guessing radius: 55 and dp: 7.0 vote threshold: 12
# guessing radius: 50 and dp: 7.0 vote threshold: 12
# guessing radius: 45 and dp: 7.0 vote threshold: 12
# guessing radius: 40 and dp: 7.0 vote threshold: 12
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 12
# guessing radius: 65 and dp: 8.5 vote threshold: 12
# guessing radius: 60 and dp: 8.5 vote threshold: 12
# guessing radius: 55 and dp: 8.5 vote threshold: 12
# guessing radius: 50 and dp: 8.5 vote threshold: 12
# guessing radius: 45 and dp: 8.5 vote threshold: 12
# guessing radius: 40 and dp: 8.5 vote threshold: 12
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 10
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 10
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 10
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 10
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 10
# guessing radius: 65 and dp: 7.0 vote threshold: 10
# guessing radius: 60 and dp: 7.0 vote threshold: 10
# guessing radius: 55 and dp: 7.0 vote threshold: 10
# guessing radius: 50 and dp: 7.0 vote threshold: 10
# guessing radius: 45 and dp: 7.0 vote threshold: 10
# guessing radius: 40 and dp: 7.0 vote threshold: 10
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 10
# guessing radius: 65 and dp: 8.5 vote threshold: 10
# guessing radius: 60 and dp: 8.5 vote threshold: 10
# guessing radius: 55 and dp: 8.5 vote threshold: 10
# guessing radius: 50 and dp: 8.5 vote threshold: 10
# guessing radius: 45 and dp: 8.5 vote threshold: 10
# guessing radius: 40 and dp: 8.5 vote threshold: 10
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 8
# len of circles: 1
# k1
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 8
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 8
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 8
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 8
# guessing radius: 65 and dp: 7.0 vote threshold: 8
# guessing radius: 60 and dp: 7.0 vote threshold: 8
# guessing radius: 55 and dp: 7.0 vote threshold: 8
# guessing radius: 50 and dp: 7.0 vote threshold: 8
# guessing radius: 45 and dp: 7.0 vote threshold: 8
# guessing radius: 40 and dp: 7.0 vote threshold: 8
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 8
# guessing radius: 65 and dp: 8.5 vote threshold: 8
# guessing radius: 60 and dp: 8.5 vote threshold: 8
# guessing radius: 55 and dp: 8.5 vote threshold: 8
# guessing radius: 50 and dp: 8.5 vote threshold: 8
# guessing radius: 45 and dp: 8.5 vote threshold: 8
# guessing radius: 40 and dp: 8.5 vote threshold: 8
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 6
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 6
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 6
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 6
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 6
# guessing radius: 65 and dp: 7.0 vote threshold: 6
# guessing radius: 60 and dp: 7.0 vote threshold: 6
# guessing radius: 55 and dp: 7.0 vote threshold: 6
# guessing radius: 50 and dp: 7.0 vote threshold: 6
# guessing radius: 45 and dp: 7.0 vote threshold: 6
# guessing radius: 40 and dp: 7.0 vote threshold: 6
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 6
# guessing radius: 65 and dp: 8.5 vote threshold: 6
# guessing radius: 60 and dp: 8.5 vote threshold: 6
# guessing radius: 55 and dp: 8.5 vote threshold: 6
# guessing radius: 50 and dp: 8.5 vote threshold: 6
# guessing radius: 45 and dp: 8.5 vote threshold: 6
# guessing radius: 40 and dp: 8.5 vote threshold: 6
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 4
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 4
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 4
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 4
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 4
# guessing radius: 65 and dp: 7.0 vote threshold: 4
# guessing radius: 60 and dp: 7.0 vote threshold: 4
# guessing radius: 55 and dp: 7.0 vote threshold: 4
# guessing radius: 50 and dp: 7.0 vote threshold: 4
# guessing radius: 45 and dp: 7.0 vote threshold: 4
# guessing radius: 40 and dp: 7.0 vote threshold: 4
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 4
# guessing radius: 65 and dp: 8.5 vote threshold: 4
# guessing radius: 60 and dp: 8.5 vote threshold: 4
# guessing radius: 55 and dp: 8.5 vote threshold: 4
# guessing radius: 50 and dp: 8.5 vote threshold: 4
# guessing radius: 45 and dp: 8.5 vote threshold: 4
# guessing radius: 40 and dp: 8.5 vote threshold: 4
# resetting guess_dp:1.0
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 1.0 vote threshold: 2
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 2.5 vote threshold: 2
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 4.0 vote threshold: 2
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 5.5 vote threshold: 2
# setting guess_radius: 70
# False
# guessing radius: 70 and dp: 7.0 vote threshold: 2
# guessing radius: 65 and dp: 7.0 vote threshold: 2
# guessing radius: 60 and dp: 7.0 vote threshold: 2
# guessing radius: 55 and dp: 7.0 vote threshold: 2
# guessing radius: 50 and dp: 7.0 vote threshold: 2
# guessing radius: 45 and dp: 7.0 vote threshold: 2
# guessing radius: 40 and dp: 7.0 vote threshold: 2
# setting guess_radius: 70
# True
# guessing radius: 70 and dp: 8.5 vote threshold: 2
# guessing radius: 65 and dp: 8.5 vote threshold: 2
# guessing radius: 60 and dp: 8.5 vote threshold: 2
# guessing radius: 55 and dp: 8.5 vote threshold: 2
# guessing radius: 50 and dp: 8.5 vote threshold: 2
# guessing radius: 45 and dp: 8.5 vote threshold: 2
# guessing radius: 40 and dp: 8.5 vote threshold: 2
# None
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[126.25     118.75      41.256817]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[101.75   145.75    70.8352]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[106.       142.        69.065186]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[103.75   141.25    71.0044]]
# [[129.5      165.5       41.599277]]
# [[150.5      134.5       66.562004]]
# [[154.5     138.5      71.76698]]
# [[154.5     138.5      71.76698]]
# [[154.5     138.5      71.76698]]
# [[154.5     138.5      71.76698]]
